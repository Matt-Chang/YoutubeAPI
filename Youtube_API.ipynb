# %% [markdown]
# <a href="https://colab.research.google.com/github/Matt-Chang/YoutubeAPI/blob/main/Youtube_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
import pandas as pd 
import time

# %%
API_KEY = 'AIzaSyCZwSZvCHRyV6Pqlg5t1mPuXLgmqSOXKQg'
channel_id= 'UCiT9RITQ9PW6BhXK0y2jaeg'

# %%
def get_video_details(video_id):

      url_video_stats ='https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+API_KEY
      response_url_video_stats = requests.get(url_video_stats).json()

      view_Count = response_url_video_stats['items'][0]['statistics']['viewCount']
      like_Count = response_url_video_stats['items'][0]['statistics']['likeCount']
      favorite_Count = response_url_video_stats['items'][0]['statistics']['favoriteCount']
      comment_Count = response_url_video_stats['items'][0]['statistics']['commentCount']
      
      return view_Count,like_Count,favorite_Count,comment_Count

# %%
def get_video(df):

    # make API call 
    pageToken = ''
    url ='https://www.googleapis.com/youtube/v3/search?key='+API_KEY+'&channelId='+channel_id+'&part=snippet,id&order=date&maxResults=10000'+pageToken
    response = requests.get(url).json()

    time.sleep(1)

    for video in response['items']:
      if video['id']['kind']=='youtube#video':
          video_id = video['id']['videoId']
          video_title = video['snippet']['title']
          upload_date = video['snippet']['publishedAt']
          upload_date = str(upload_date).split('T')[0]

          view_Count,like_Count,favorite_Count,comment_Count = get_video_details(video_id)

          #save data in panda df
          df = df.append({'video_id':video_id,'video_title':video_title,'upload_date':upload_date,'view_Count':view_Count,'like_Count':like_Count,'favorite_Count':favorite_Count,'comment_Count':comment_Count},ignore_index=True)

    return df

# %%
#build a dataframe
df = pd.DataFrame(columns=['video_id','video_title','upload_date','view_Count','like_Count','favorite_Count','comment_Count'])
df = get_video(df)
df.to_csv('API.csv',encoding ='utf-8',index = False)
df.to_excel('API.xls',encoding ='utf-8',index = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   """

# %%
pd.read_csv('API.csv')
# Out:
#        video_id                                        video_title  \
# 0   QMP858aZcow  5 Impactful Data Science Projects For Your Por...
# 1   0ItYIoOrrUs        Can Machine Learning Fix My Baseball Swing?
# 2   KzTFoUbThvM                   Every Data Scientist... (funny!)
# 3   bBJd0oPdNak  State of Data Science (Town Hall) ft - Data Squad
# 4   Yk-unX4KnV4  Data Science Portfolio Project From Scratch | ...
# 5   z0_xrtFdFj8          Why You Are NOT Landing Data Jobs ... Yet
# 6   vVpkXEIn-q0   Can Data Defeat This Deceitful OpenSea NFT Scam?
# 7   aipz4p7GDL4  When a PM Joins the Data Team... (funny!) - Ft...
# 8   iPdO9MwdcLE      What Professional Data Scientists ACTUALLY Do
# 9   YPph59-rTxA         Can You Analyze My Data Better Than I Can?
# 10  -2U2CMYom00        Giving Back to My Most Engaged Subscribers!
# 11  KEeUR8UDy-s  How to Make $1 Billion Betting on Horse Racing...
# 12  0jTtHYie3CU  Should You Be Excited About Web 3? (As a Data ...
# 13  2RWwN5ZT4tA  Should  @Luke Barousse Take This Data Analyst ...
# 14  rEWPqw6rMGI         The Only Data Science Explanation You Need
# 15  o-wsyxWbPOw  We Need to Talk About The LinkedIn Machine Lea...
# 16  xpIFS6jZbe8  How I Would Learn Data Science in 2022 (If I H...
# 17  -zbLpoJVBMI     What the Heck is WSL 2? (My New Favorite Tool)
# 18  scSc6YSanQ0  How Statistics Saved the US SERIOUS $$$$ Durin...
# 19  FqNpDNmpcEo  How Zillow Lost $500 MILLION With Machine Lear...
# 20  vwvdtXMcNzI          Why Is Data Engineering So HOT Right Now?
# 21  2qVWurPFwfc                             Is Data Science Dying?
# 22  35g8fCi-kbw  7 Incredible Books That Transformed My Health ...
# 23  n6MiRgxN5iA  Why EVERYONE Should Start a Podcast (Including...
# 24  ammCGdzSoag  Building a Burrito Dashboard - Data Science Pr...
# 25  15c7WD-lKUY                         ML Ops: What is it REALLY?
# 26  TjGFBQC27ng  Business Skills for Data Science: What are the...
# 27  qUK5Vk4NvBw  #66DaysOfData Round 3 Live Event! (feat. @Stat...
# 28  cnqTU6eJwH0  Roasting My First Data Science Project (Common...
# 29  k8YxyrcAXJs  Is Data Visualization Important for Data Scien...
# 30  VvnOXDCVm8k  Project Presentation - Expectations vs. Realit...
# 31  68GGPK3WaqI  Data Science Project - Expectations vs Reality...
# 32  S4Lei5mOppc                            How I Learned to Learn.
# 33  tG_UW_p0UqE          Is Spotify Shuffle Really Random? #Shorts
# 34  143WWA5Sy9k  I Eat a Papaya Live on Stream (Plus Q&amp;A fo...
# 35  s1gD35Z4eUc           Why are APIs Important for Data Science?
# 36  nrEJGGxcoTc             Is Your Phone REALLY Listening to You?
# 37  KfpOuSH9gDc  Kaggle vs Github - Which is Best for Your Data...
# 38  sICJ6a2wX5g                #66DaysOfData - 3 Reasons to Start!
# 39  iiSZqsQKNX8                #66DaysOfData - What is it? #shorts
# 40  IoUWD1h6xUs          A Quick Data Science Project Tip! #SHORTS
# 41  7JCterBrcvk  Discouraged with Data Science? - Watch THIS vi...
# 42  KU__lDJj5iU                  How Data Science Projects Pay Off
# 43  8nTmuKI2oyA  How I Use Data to Optimize My Life | What I Co...
# 44  SaWxVk7rDp4        What is a lambda function (python)? #shorts
# 45  n7kjelw9s2w  Why Kaggle Should Be Your Favorite Data Scienc...
# 46  8Pi36Nj6P9A  What is Pandas? (Data &amp; Data Science) #shorts
#
#    upload_date  view_Count  like_Count  favorite_Count  comment_Count
# 0   2022-06-27       15133         926               0             64
# 1   2022-06-10        5595         285               0             67
# 2   2022-05-24       10593         653               0            140
# 3   2022-05-07       14895         415               0             65
# 4   2022-04-04       29712         901               0             81
# 5   2022-03-25       13360         605               0             96
# 6   2022-03-03        4273         180               0             51
# 7   2022-02-21        8706         428               0            141
# 8   2022-02-14       70716        2462               0            169
# 9   2022-01-31        5832         298               0             64
# 10  2022-01-28        2148         117               0             89
# 11  2022-01-24        9388         498               0             64
# 12  2022-01-17        7646         400               0             80
# 13  2022-01-14        5388         148               0             32
# 14  2022-01-10       23208        1354               0            159
# 15  2022-01-03       13276         625               0            150
# 16  2021-12-27      227352       10698               0            437
# 17  2021-12-17        6818         297               0             56
# 18  2021-12-10        5340         365               0             21
# 19  2021-12-03       20813        1042               0            151
# 20  2021-11-26       25466         971               0            135
# 21  2021-11-19       92072        3009               0            318
# 22  2021-11-12        7267         372               0            112
# 23  2021-11-05        3482         195               0             48
# 24  2021-10-29        8091         221               0             30
# 25  2021-10-22        4718         227               0             61
# 26  2021-10-18        5973         277               0             50
# 27  2021-10-12        2157         123               0              5
# 28  2021-10-08        5138         265               0             67
# 29  2021-08-20       11384         502               0            111
# 30  2021-08-07        7239         267               0             32
# 31  2021-08-06       24902         905               0             31
# 32  2021-07-31       36368        1885               0            188
# 33  2021-07-21        7742         445               0             48
# 34  2021-07-16        2328          93               0             30
# 35  2021-07-09        7711         389               0             92
# 36  2021-07-03        4782         273               0            118
# 37  2021-06-25       10661         486               0            125
# 38  2021-06-18        3648         194               0             40
# 39  2021-06-11        7284         324               0             53
# 40  2021-06-03       13667         766               0             87
# 41  2021-05-28        7136         380               0            201
# 42  2021-05-22        9823         570               0            149
# 43  2021-05-14        9821         461               0            138
# 44  2021-05-13        9670         627               0             47
# 45  2021-05-07       16652         749               0             60
# 46  2021-04-30       15551         653               0             93

# %%
df
# Out:
#        video_id                                        video_title  \
# 0   QMP858aZcow  5 Impactful Data Science Projects For Your Por...
# 1   0ItYIoOrrUs        Can Machine Learning Fix My Baseball Swing?
# 2   KzTFoUbThvM                   Every Data Scientist... (funny!)
# 3   bBJd0oPdNak  State of Data Science (Town Hall) ft - Data Squad
# 4   Yk-unX4KnV4  Data Science Portfolio Project From Scratch | ...
# 5   z0_xrtFdFj8          Why You Are NOT Landing Data Jobs ... Yet
# 6   vVpkXEIn-q0   Can Data Defeat This Deceitful OpenSea NFT Scam?
# 7   aipz4p7GDL4  When a PM Joins the Data Team... (funny!) - Ft...
# 8   iPdO9MwdcLE      What Professional Data Scientists ACTUALLY Do
# 9   YPph59-rTxA         Can You Analyze My Data Better Than I Can?
# 10  -2U2CMYom00        Giving Back to My Most Engaged Subscribers!
# 11  KEeUR8UDy-s  How to Make $1 Billion Betting on Horse Racing...
# 12  0jTtHYie3CU  Should You Be Excited About Web 3? (As a Data ...
# 13  2RWwN5ZT4tA  Should  @Luke Barousse Take This Data Analyst ...
# 14  rEWPqw6rMGI         The Only Data Science Explanation You Need
# 15  o-wsyxWbPOw  We Need to Talk About The LinkedIn Machine Lea...
# 16  xpIFS6jZbe8  How I Would Learn Data Science in 2022 (If I H...
# 17  -zbLpoJVBMI     What the Heck is WSL 2? (My New Favorite Tool)
# 18  scSc6YSanQ0  How Statistics Saved the US SERIOUS $$$$ Durin...
# 19  FqNpDNmpcEo  How Zillow Lost $500 MILLION With Machine Lear...
# 20  vwvdtXMcNzI          Why Is Data Engineering So HOT Right Now?
# 21  2qVWurPFwfc                             Is Data Science Dying?
# 22  35g8fCi-kbw  7 Incredible Books That Transformed My Health ...
# 23  n6MiRgxN5iA  Why EVERYONE Should Start a Podcast (Including...
# 24  ammCGdzSoag  Building a Burrito Dashboard - Data Science Pr...
# 25  15c7WD-lKUY                         ML Ops: What is it REALLY?
# 26  TjGFBQC27ng  Business Skills for Data Science: What are the...
# 27  qUK5Vk4NvBw  #66DaysOfData Round 3 Live Event! (feat. @Stat...
# 28  cnqTU6eJwH0  Roasting My First Data Science Project (Common...
# 29  k8YxyrcAXJs  Is Data Visualization Important for Data Scien...
# 30  VvnOXDCVm8k  Project Presentation - Expectations vs. Realit...
# 31  68GGPK3WaqI  Data Science Project - Expectations vs Reality...
# 32  S4Lei5mOppc                            How I Learned to Learn.
# 33  tG_UW_p0UqE          Is Spotify Shuffle Really Random? #Shorts
# 34  143WWA5Sy9k  I Eat a Papaya Live on Stream (Plus Q&amp;A fo...
# 35  s1gD35Z4eUc           Why are APIs Important for Data Science?
# 36  nrEJGGxcoTc             Is Your Phone REALLY Listening to You?
# 37  KfpOuSH9gDc  Kaggle vs Github - Which is Best for Your Data...
# 38  sICJ6a2wX5g                #66DaysOfData - 3 Reasons to Start!
# 39  iiSZqsQKNX8                #66DaysOfData - What is it? #shorts
# 40  IoUWD1h6xUs          A Quick Data Science Project Tip! #SHORTS
# 41  7JCterBrcvk  Discouraged with Data Science? - Watch THIS vi...
# 42  KU__lDJj5iU                  How Data Science Projects Pay Off
# 43  8nTmuKI2oyA  How I Use Data to Optimize My Life | What I Co...
# 44  SaWxVk7rDp4        What is a lambda function (python)? #shorts
# 45  n7kjelw9s2w  Why Kaggle Should Be Your Favorite Data Scienc...
# 46  8Pi36Nj6P9A  What is Pandas? (Data &amp; Data Science) #shorts
#
#    upload_date view_Count like_Count favorite_Count comment_Count
# 0   2022-06-27      15133        926              0            64
# 1   2022-06-10       5595        285              0            67
# 2   2022-05-24      10593        653              0           140
# 3   2022-05-07      14895        415              0            65
# 4   2022-04-04      29712        901              0            81
# 5   2022-03-25      13360        605              0            96
# 6   2022-03-03       4273        180              0            51
# 7   2022-02-21       8706        428              0           141
# 8   2022-02-14      70714       2462              0           169
# 9   2022-01-31       5832        298              0            64
# 10  2022-01-28       2148        117              0            89
# 11  2022-01-24       9386        498              0            64
# 12  2022-01-17       7646        400              0            80
# 13  2022-01-14       5388        148              0            32
# 14  2022-01-10      23208       1354              0           159
# 15  2022-01-03      13276        625              0           150
# 16  2021-12-27     227336      10698              0           437
# 17  2021-12-17       6818        297              0            56
# 18  2021-12-10       5340        365              0            21
# 19  2021-12-03      20813       1042              0           151
# 20  2021-11-26      25466        971              0           135
# 21  2021-11-19      92068       3009              0           318
# 22  2021-11-12       7267        372              0           112
# 23  2021-11-05       3482        195              0            48
# 24  2021-10-29       8091        221              0            30
# 25  2021-10-22       4718        227              0            61
# 26  2021-10-18       5973        277              0            50
# 27  2021-10-12       2157        123              0             5
# 28  2021-10-08       5138        265              0            67
# 29  2021-08-20      11384        502              0           111
# 30  2021-08-07       7239        267              0            32
# 31  2021-08-06      24902        905              0            31
# 32  2021-07-31      36367       1885              0           188
# 33  2021-07-21       7742        444              0            48
# 34  2021-07-16       2328         93              0            30
# 35  2021-07-09       7711        389              0            92
# 36  2021-07-03       4782        273              0           118
# 37  2021-06-25      10661        486              0           125
# 38  2021-06-18       3648        194              0            40
# 39  2021-06-11       7284        324              0            53
# 40  2021-06-03      13666        766              0            87
# 41  2021-05-28       7136        380              0           201
# 42  2021-05-22       9823        570              0           149
# 43  2021-05-14       9821        461              0           138
# 44  2021-05-13       9670        627              0            47
# 45  2021-05-07      16652        749              0            60
# 46  2021-04-30      15551        653              0            93

# %%
# !pip install psycopg2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.7/dist-packages (2.7.6.1)

# %%
import psycopg2 as ps

# %%
def connect_to_db(host_name, dbname, port, username, password):
    try:
        conn = ps.connect(host=host_name, database=dbname, user=username, password=password, port=port)

    except ps.OperationalError as e:
        raise e
    else:
        print('Connected!')
        return conn

def create_table(curr):
    create_table_command = ("""CREATE TABLE IF NOT EXISTS videos (
                    video_id varchar PRIMARY KEY,
                    video_title TEXT NOT NULL,
                    upload_date DATE NOT NULL DEFAULT CURRENT_DATE,
                    view_count varchar NOT NULL,
                    like_count varchar NOT NULL,
                    favorite_Count Integer NOT NULL,
                    comment_count varchar NOT NULL
            )""")

    curr.execute(create_table_command)

def insert_into_table(curr, video_id, video_title, upload_date, view_count, like_count, favorite_Count, comment_count):
    insert_into_videos = ("""INSERT INTO videos (video_id, video_title, upload_date,
                        view_count, like_count, favorite_Count,comment_count)
    VALUES(%s,%s,%s,%s,%s,%s,%s);""")
    row_to_insert = (video_id, video_title, upload_date, view_count, like_count, favorite_Count, comment_count)
    curr.execute(insert_into_videos, row_to_insert)


def update_row(curr, video_id, video_title, view_count, like_count, favorite_Count, comment_count):
    query = ("""UPDATE videos
            SET video_title = %s,
                view_count = %s,
                like_count = %s,
                favorite_Count = %s,
                comment_count = %s
            WHERE video_id = %s;""")
    vars_to_update = (video_title, view_count, like_count, favorite_Count, comment_count, video_id)
    curr.execute(query, vars_to_update)


def check_if_video_exists(curr, video_id): 
    query = ("""SELECT video_id FROM VIDEOS WHERE video_id = %s""")

    curr.execute(query, (video_id,))
    return curr.fetchone() is not None


def truncate_table(curr):
    truncate_table = ("""TRUNCATE TABLE videos""")

    curr.execute(truncate_table)


def append_from_df_to_db(curr,df):
    for i, row in df.iterrows():
        insert_into_table(curr, row['video_id'], row['video_title'], row['upload_date'], row['view_count']
                          , row['like_count'], row['favorite_Count'], row['comment_count'])


def update_db(curr,df):
    tmp_df = pd.DataFrame(columns=['video_id', 'video_title', 'upload_date', 'view_count',
                                   'like_count', 'favorite_Count', 'comment_count'])
    for i, row in df.iterrows():
        if check_if_video_exists(curr, row['video_id']): 
            update_row(curr,row['video_id'],row['video_title'],row['view_count'],row['like_count'],row['favorite_Count'],row['comment_count'])
        else: # The video doesn't exists so we will add it to a temp df and append it using append_from_df_to_db
            tmp_df = tmp_df.append(row)

    return tmp_df

# %%
host_name = 'matt-database-1.cdbgbvurfemt.us-west-2.rds.amazonaws.com'
dbname = 'MattChang'
port = '5432'
username = 'MattDB' 
password = '12345678'
conn = None

conn = connect_to_db(host_name, dbname, port, username, password)
curr = conn.cursor()
# Out:
# Connected!

# %%
new_vid_df = update_db(curr,df)
conn.commit()

# %%
create_table(curr)

# %%
conn.commit()

# %%
append_from_df_to_db(curr, new_vid_df)

# %%
conn.commit()

# %%
curr.execute("SELECT * FROM VIDEOS")
print(curr.fetchall())
# Out:
# [('QMP858aZcow', '5 Impactful Data Science Projects For Your Portfolio', datetime.date(2022, 6, 27), 'NaN', 'NaN', 0, 'NaN'), ('0ItYIoOrrUs', 'Can Machine Learning Fix My Baseball Swing?', datetime.date(2022, 6, 10), 'NaN', 'NaN', 0, 'NaN'), ('KzTFoUbThvM', 'Every Data Scientist... (funny!)', datetime.date(2022, 5, 24), 'NaN', 'NaN', 0, 'NaN'), ('bBJd0oPdNak', 'State of Data Science (Town Hall) ft - Data Squad', datetime.date(2022, 5, 7), 'NaN', 'NaN', 0, 'NaN'), ('Yk-unX4KnV4', 'Data Science Portfolio Project From Scratch | Building a YouTube Data Dashboard with Streamlit', datetime.date(2022, 4, 4), 'NaN', 'NaN', 0, 'NaN'), ('z0_xrtFdFj8', 'Why You Are NOT Landing Data Jobs ... Yet', datetime.date(2022, 3, 25), 'NaN', 'NaN', 0, 'NaN'), ('vVpkXEIn-q0', 'Can Data Defeat This Deceitful OpenSea NFT Scam?', datetime.date(2022, 3, 3), 'NaN', 'NaN', 0, 'NaN'), ('aipz4p7GDL4', 'When a PM Joins the Data Team... (funny!) - Ft @Luke Barousse', datetime.date(2022, 2, 21), 'NaN', 'NaN', 0, 'NaN'), ('iPdO9MwdcLE', 'What Professional Data Scientists ACTUALLY Do', datetime.date(2022, 2, 14), 'NaN', 'NaN', 0, 'NaN'), ('YPph59-rTxA', 'Can You Analyze My Data Better Than I Can?', datetime.date(2022, 1, 31), 'NaN', 'NaN', 0, 'NaN'), ('-2U2CMYom00', 'Giving Back to My Most Engaged Subscribers!', datetime.date(2022, 1, 28), 'NaN', 'NaN', 0, 'NaN'), ('KEeUR8UDy-s', 'How to Make $1 Billion Betting on Horse Racing with Machine Learning', datetime.date(2022, 1, 24), 'NaN', 'NaN', 0, 'NaN'), ('0jTtHYie3CU', 'Should You Be Excited About Web 3? (As a Data Scientist)', datetime.date(2022, 1, 17), 'NaN', 'NaN', 0, 'NaN'), ('2RWwN5ZT4tA', 'Should  @Luke Barousse Take This Data Analyst Job? (Funny) #Shorts', datetime.date(2022, 1, 14), 'NaN', 'NaN', 0, 'NaN'), ('rEWPqw6rMGI', 'The Only Data Science Explanation You Need', datetime.date(2022, 1, 10), 'NaN', 'NaN', 0, 'NaN'), ('o-wsyxWbPOw', 'We Need to Talk About The LinkedIn Machine Learning Assessment.', datetime.date(2022, 1, 3), 'NaN', 'NaN', 0, 'NaN'), ('xpIFS6jZbe8', 'How I Would Learn Data Science in 2022 (If I Had to Start Over)', datetime.date(2021, 12, 27), 'NaN', 'NaN', 0, 'NaN'), ('-zbLpoJVBMI', 'What the Heck is WSL 2? (My New Favorite Tool)', datetime.date(2021, 12, 17), 'NaN', 'NaN', 0, 'NaN'), ('scSc6YSanQ0', 'How Statistics Saved the US SERIOUS $$$$ During WW2 #Shorts', datetime.date(2021, 12, 10), 'NaN', 'NaN', 0, 'NaN'), ('FqNpDNmpcEo', 'How Zillow Lost $500 MILLION With Machine Learning', datetime.date(2021, 12, 3), 'NaN', 'NaN', 0, 'NaN'), ('vwvdtXMcNzI', 'Why Is Data Engineering So HOT Right Now?', datetime.date(2021, 11, 26), 'NaN', 'NaN', 0, 'NaN'), ('2qVWurPFwfc', 'Is Data Science Dying?', datetime.date(2021, 11, 19), 'NaN', 'NaN', 0, 'NaN'), ('35g8fCi-kbw', '7 Incredible Books That Transformed My Health and My Life', datetime.date(2021, 11, 12), 'NaN', 'NaN', 0, 'NaN'), ('n6MiRgxN5iA', 'Why EVERYONE Should Start a Podcast (Including YOU)', datetime.date(2021, 11, 5), 'NaN', 'NaN', 0, 'NaN'), ('ammCGdzSoag', 'Building a Burrito Dashboard - Data Science Project from Scratch with atoti', datetime.date(2021, 10, 29), 'NaN', 'NaN', 0, 'NaN'), ('15c7WD-lKUY', 'ML Ops: What is it REALLY?', datetime.date(2021, 10, 22), 'NaN', 'NaN', 0, 'NaN'), ('TjGFBQC27ng', 'Business Skills for Data Science: What are they REALLY?', datetime.date(2021, 10, 18), 'NaN', 'NaN', 0, 'NaN'), ('qUK5Vk4NvBw', '#66DaysOfData Round 3 Live Event! (feat. @StatQuest with Josh Starmer)', datetime.date(2021, 10, 12), 'NaN', 'NaN', 0, 'NaN'), ('cnqTU6eJwH0', 'Roasting My First Data Science Project (Common Project Mistakes)', datetime.date(2021, 10, 8), 'NaN', 'NaN', 0, 'NaN'), ('k8YxyrcAXJs', 'Is Data Visualization Important for Data Science? (A Data Scientist&#39;s Perspective)', datetime.date(2021, 8, 20), 'NaN', 'NaN', 0, 'NaN'), ('VvnOXDCVm8k', 'Project Presentation - Expectations vs. Reality (funny) #shorts', datetime.date(2021, 8, 7), 'NaN', 'NaN', 0, 'NaN'), ('68GGPK3WaqI', 'Data Science Project - Expectations vs Re ...
